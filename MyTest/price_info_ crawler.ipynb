# %%
import requests
import re
import time
 
def getHTMLText(url):
    try:
        r = requests.get(url, timeout = 30)#设定超时时间
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return print("解析网页失败")
def parsePage(li, html):
    try:
        counts = re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)#正则获取价格
        names = re.findall(r'\"raw_title\"\:\".*?\"',html)#正则获取名字
        for i in range(len(counts)):
            price = eval(counts[i].split(':')[1])#以:分割，获取价格，同时删除引号等符号
            title = eval(names[i].split(':')[1])
            li.append([price, title])
    except:
        print("爬取失败")
 
 
def printGoodList(lis):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号","价格","产品信息"))
    num = 1
    for g in lis:
        num = num + 1
        print(tplt.format(num, g[0], g[1]))
    
def get_meanprice(list):
    num = 1.0
    sum_price = 0.0
    for x in list:
        sum_price = sum_price + float([0])
        num = num + 1
    mean_price = sum_price/sum
    print("平均价格：",mean_price)
    
if __name__ == '__main__':
    goods = "the north face"
    depth = 3
    start_url = 'http://s.taobao.com/search?q=' + goods
    list = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(list,html)
        except:
            continue
    printGoodList(list)
    get_meanprice(list)
# Out:
# 序号  	价格      	产品信息
#    2	548.00  	外套抓绒冲锋衣北面户外秋冬男抓绒衣保暖
#    3	1698.00 	【经典款】TheNorthFace北面防水三合一男冲锋衣男秋冬上新|3RKA
#    4	1598.00 	【经典款】TheNorthFace北面羽绒外套男舒适保暖秋冬上新|3RKB
#    5	988.00  	THENORTHFACE北面短款羽绒服暴力橙冠希同款TNF1996NUPTSEJACKET
#    6	399.00  	17fw潮牌日版冠军联名北面tnf暴力橙1996羽绒服男supreme雪山外套
#    7	2199.00 	侃爷同款The North Face 北面羽绒服男新款 1992 Nuptse 紫色黑色
#    8	1259.00 	东飞正品The North Face北面羽绒服男女TNF经典两色老款短外套NFD
#    9	1599.00 	The North Face 北面 TNF 1996 NUPTSE Supreme联名版型 黑橙
#   10	2499.00 	The North Face 1996 NUPTSE TNF黑橙/蓝/灰北面羽服绒 NJ1DJ58
#   11	2599.00 	现货 THE NORTH FACE日本北面 Nuptse Jacket 防水羽绒服 陈冠希
#   12	5800.00 	一通日本代购 TNF 北面 18AW 毛领极地羽绒服大鹅男女外套ND91807
#   13	5299.00 	姚家军 Supreme The North Face Expedition Jacket TNF 18冲锋衣
#   14	2580.00 	持续更新 TNF 18FW THE NORTH FACE 700 PUFFY JACKET 羽绒服外套
#   15	4220.00 	18AW紫标JS联名65/35 Mountain short down parka羽绒服日本代购
#   16	1349.00 	The North Face 北面  1996 NUPTSE 暴力橙/迷彩/黑/黄 TNF羽绒服
#   17	4630.00 	SODA日本现货THE NORTH FACE北面MOUNTAIN DOWN JACKET羽绒服外套
#   18	4999.00 	理性 Supreme The North Face Expedition Jacket TNF 18FW冲锋衣
#  109	299.00  	TheNorthFace北面棉衣加厚冬季韩版棉服袄男士中长款外套潮流帅气
#  110	520.00  	TheNorthFace北面白鸭绒短款羽绒服女2018新款冬装潮宽松韩版外套
#  111	1400.00 	美国代购  the north face 1996 NUPTSE VEST 马甲 冲锋衣内胆
#  112	4998.00 	特价现货秒发Mastermind x The North Face TNF mmj Nuptse羽绒服
#  113	529.00  	正品THE NORTH FACE北面羽绒服男中长款加厚保暖户外防风防水外套
#  114	855.00  	现货 18AW THE NORTH FACE紫标X-PAC SHOULDER POCKET挎包肩包TNF
#  115	198.00  	THE NORTH FACE北面秋冬季男女运动休闲卫衣连帽套头衫外套加绒潮
#  116	398.00  	THE NORTH FACE北面男女冲锋机能棉服棉衣防风衣外套运动保暖棉袄
#  117	289.00  	TheNorthFace北面男士外套冬季韩版潮流加厚羽绒棉服棉袄子羊羔毛
#  118	588.00  	Sup reme雪山联名北面羽绒服冬季棉衣男女情侣潮牌连帽冲锋衣外套
#  119	268.00  	The North Face/北面 男士拼色羽绒服马甲 加厚立领修身背心外套
#  120	180.00  	TheNorthFace北面套头卫衣男潮流加绒加厚上衣秋冬装男士新款卫衣
#  121	1799.00 	美国直播 The North Face 北面男士中长款羽绒服外套
#  122	2828.00 	THE NORTH FACE 紫标 Reversible Field Cardigan摇粒绒夹克
#  123	10200.00	Supreme x TNF 17FW MOUNTAIN BALTORO JACKET 北脸 雪山羽绒服
#  124	4380.00 	订购 THE NORTH FACE 紫标×JS联名款 65/35 羽绒服外套夹克
#  125	2288.00 	THE NORTH FACE 紫标 Field Denali Jacket 陈冠希摇粒绒内胆外套
#  126	2750.00 	饼干家现货THE NORTH FACE 紫标 65/35 Mountain Parka四袋冲锋衣
#  127	498.00  	2019新款TNF/北面男可脱帽外套 户外修身短款拼色加厚保暖羽绒服
#  128	228.00  	TheNorthFace北面卫衣新款女长袖韩版宽松ins连帽情侣加厚加绒
#  129	1345.00 	THE NORTH FACE日本北面DENALI JACKET摇粒绒抓绒夹克日版NA71831
#  130	268.00  	THE NORTH FACE/北面正品秋冬外套男加厚棉衣棉服男子户外运动服
#  131	238.00  	TheNorthFace北面秋新款加绒加厚运动裤男宽松休闲裤束脚裤卫裤男
#  132	198.00  	The North Face北面立领连帽反光加绒连帽卫衣外套男女套头衫复古
#  133	4860.00 	小新家日本代购 TNF 北面 18AW 毛领极地羽绒服光电子男女ND91820
#  134	188.00  	TheNorthFace北面羽绒马甲女韩版黑色轻薄宽松马夹加绒背心坎肩潮
#  135	268.00  	THE NORTH FACE北面男女运动休闲雪山冲锋衣防风衣连帽外套夹克潮
#  136	1999.00 	美版 The North Face 北面 1996 NUPTSE 暴力橙//黑/黄 TNF羽绒服
#  137	519.00  	纽约大宝  The North Face/北面 男士户外冲锋衣防风防雨夹克
# 平均价格： 2285.421240875912

# %%
|
