# %%
from sklearn import svm
import numpy as np
X = np.r_[np.random.randn(20,2)+[2,2],np.random.randn(20,2)-[2,2]]
y = [0]*20+[1]*20

# %%
clf = svm.SVC(kernel="linear")
clf.fit(X,y)
xx = np.linspace(-5,5)
w = clf.coef_[0]
a = -w[0]/w[1]
yy = a*xx-(clf.intercept_[0])/w[1]
print("xx:",xx)
print("clf:",clf)
print("w:",w)
print("a",a)
print("yy:",yy)
# Out:
# xx [-5.         -4.79591837 -4.59183673 -4.3877551  -4.18367347 -3.97959184
#  -3.7755102  -3.57142857 -3.36734694 -3.16326531 -2.95918367 -2.75510204
#  -2.55102041 -2.34693878 -2.14285714 -1.93877551 -1.73469388 -1.53061224
#  -1.32653061 -1.12244898 -0.91836735 -0.71428571 -0.51020408 -0.30612245
#  -0.10204082  0.10204082  0.30612245  0.51020408  0.71428571  0.91836735
#   1.12244898  1.32653061  1.53061224  1.73469388  1.93877551  2.14285714
#   2.34693878  2.55102041  2.75510204  2.95918367  3.16326531  3.36734694
#   3.57142857  3.7755102   3.97959184  4.18367347  4.3877551   4.59183673
#   4.79591837  5.        ]
# clf: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# w: [-0.8289529  -0.90755806]
# a -0.9133882776014696
# yy: [ 4.72226384  4.53585807  4.3494523   4.16304652  3.97664075  3.79023498
#   3.60382921  3.41742344  3.23101767  3.0446119   2.85820613  2.67180036
#   2.48539459  2.29898881  2.11258304  1.92617727  1.7397715   1.55336573
#   1.36695996  1.18055419  0.99414842  0.80774265  0.62133688  0.43493111
#   0.24852533  0.06211956 -0.12428621 -0.31069198 -0.49709775 -0.68350352
#  -0.86990929 -1.05631506 -1.24272083 -1.4291266  -1.61553237 -1.80193815
#  -1.98834392 -2.17474969 -2.36115546 -2.54756123 -2.733967   -2.92037277
#  -3.10677854 -3.29318431 -3.47959008 -3.66599586 -3.85240163 -4.0388074
#  -4.22521317 -4.41161894]

# %%
import matplotlib.pyplot as plt
margin = 1/np.sqrt(np.sum(clf.coef_**2))
yy_down = yy-(np.sqrt(1+a**2))*margin
yy_up = yy+(np.sqrt(1+a**2))*margin
plt.plot(xx,yy,"k-")
plt.plot(xx,yy_up,"k--")
plt.plot(xx,yy_down,"k--")
plt.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1],s=80,
            facecolors='none', zorder=10, edgecolors='k')
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
print("clf.coef_:",clf.coef_[0])
# Out:
# clf.coef_: [-0.41935079 -0.56940989]

# %%
print(w)
# Out:
# [-0.7204219  -0.55405028]

# %%
b=clf.support_vectors_[0]
yy_down = a*xx+(b[1]-a*b[0])
b=clf.support_vectors_[-1]
yy_up = a*xx+(b[1]-a*b[0])
plt.plot(xx,yy,"k-")
plt.plot(xx,yy_up,"k--")
plt.plot(xx,yy_down,"k--")
plt.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1],s=80,
            facecolors='none', zorder=10, edgecolors='k')
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()
