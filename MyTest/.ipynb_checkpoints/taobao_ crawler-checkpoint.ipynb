# %%
import requests
import re
import time
 
def getHTMLText(url):
    try:
        r = requests.get(url, timeout = 30)#设定超时时间
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return print("解析网页失败")
def parsePage(li, html):
    try:
        counts = re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)#正则获取价格
        names = re.findall(r'\"raw_title\"\:\".*?\"',html)#正则获取名字
        for i in range(len(counts)):
            price = eval(counts[i].split(':')[1])#以:分割，获取价格，同时删除引号等符号
            title = eval(names[i].split(':')[1])
            li.append([price, title])
    except:
        print("爬取失败")
 
 
def printGoodList(lis):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号","价格","产品信息"))
    num = 1
    for g in lis:
        num = num + 1
        print(tplt.format(num, g[0], g[1]))
    
def get_meanprice(list):
    num = 1.0
    sum_price = 0.0
    for x in list:
        sum_price = sum_price + float(x[0])
        num = num + 1
    mean_price = sum_price/num
    print("平均价格：",mean_price)
    
if __name__ == '__main__':
    goods = "the north face"
    depth = 3
    start_url = 'http://s.taobao.com/search?q=' + goods
    list = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(list,html)
        except:
            continue
    printGoodList(list)
    get_meanprice(list)
# Out:
# 序号  	价格      	产品信息
#    2	3398.00 	TheNorthFace北面秋冬新品55
#    3	1598.00 	【经典款】TheNorthFace北面羽绒外套男舒适保暖秋冬上新|3RKB
#    4	1378.00 	【经典款】TheNorthFace北面羽绒外套男舒适保暖秋冬上新|3V83
#    5	399.00  	17fw潮牌日版冠军联名北面tnf暴力橙1996羽绒服男supreme雪山外套
#    6	1599.00 	The North Face 北面 TNF 1996 NUPTSE Supreme联名版型 黑橙
#    7	2999.00 	侃爷同款The North Face 北面羽绒服男新款 1992 Nuptse 紫色黑色
#    8	1259.00 	东飞正品The North Face北面羽绒服男女TNF经典两色老款短外套NFD
#    9	1849.00 	The North Face 1996 NUPTSE TNF暴力橙/蓝/灰北面羽绒服 NJ1DJ58
#   10	2599.00 	现货 THE NORTH FACE日本北面 Nuptse Jacket 防水羽绒服 陈冠希
#   11	5800.00 	一通日本代购 TNF 北面 18AW 毛领极地羽绒服大鹅男女外套ND91807
#   12	6222.00 	Supreme x The North Face 17FW联名TNF雪山冲锋衣夹克男女羽绒服
#   13	2326.55 	TNF北面TheNorthFace 1996 暴力橙 紫色 黑1992 侃爷 冠希 羽绒服
#   14	5299.00 	姚家军 Supreme The North Face Expedition Jacket TNF 18冲锋衣
#   15	6699.00 	Supreme x The North Face 18FW WEEK15 TNF联名 拼色冲锋衣
#   16	4630.00 	SODA日本现货THE NORTH FACE北面MOUNTAIN DOWN JACKET羽绒服外套
#   17	4220.00 	18AW紫标JS联名65/35 Mountain short down parka羽绒服日本代购
#   18	650.00  	TNF/北面 THE NORTH FACE 陈冠希同款羽绒服ND91841北脸男装加厚
